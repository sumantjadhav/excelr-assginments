# %%
import requests 
from bs4 import BeautifulSoup as bs
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
redmi_reviews = []

# %%
for i in range (1,21):
    ip=[]
    url ="https://www.amazon.in/Redmi-Pro-Blue-64GB-Storage/product-reviews/B07DJHR5DY/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber="+str(i)
    response = requests.get(url)
    soup = bs(response.content,"html.parser")
    reviews = soup.findAll("span",attrs = {"class","a-size-base review-text review-text-content"})
    for i in range(len(reviews)):
        ip.append(reviews[i].text)
    redmi_reviews = redmi_reviews+ip

# %%
with open("redmi.txt","w",encoding = 'utf-8') as output:
    output.write(str(redmi_reviews))

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\suman\\Downloads\\excelr datascince\\Untitled Folder'

# %%
red_rev_string = " ".join(redmi_reviews)

# %%
red_rev_string = re.sub("[^A-Za-z" "]+"," ",red_rev_string).lower()
red_rev_string =re.sub("[0-9" "]+"," ",red_rev_string)

# %%
red_rev_words = red_rev_string.split(" ")

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\suman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
red_rev_words = [w for w in red_rev_words if not w in stop_words]

# %%
wordcloud_ip = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(red_rev_string)

# %%
plt.imshow(wordcloud_ip)

# %%
with open(r"C:\Users\suman\Downloads\negative-words.txt") as neg:
  negwords = neg.read().split("\n")

# %%
negwords =negwords[37:]

# %%
red_pos = " ".join([w for w in red_rev_words if w in negwords])

# %%
wordcloud_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(red_pos)

plt.imshow(wordcloud_pos)

# %%
red_unique = list(set(" ".join(redmi_reviews).split(" ")))

# %%
red_unique
# Out:
# ['',
#  'model.The',
#  'leader',
#  'models',
#  'lithium-polymer',
#  'saw',
#  'clear',
#  'Mi.',
#  '26',
#  'app',
#  'reliability',
#  'talk',
#  'later',
#  'colourCamera*12',
#  'month',
#  'Photo',
#  'utilized',
#  '2g',
#  'budget.\n',
#  'sexy,',
#  'segment.Offers',
#  'acceptable',
#  'manufacturer',
#  '13k',
#  'S5K5E8',
#  '?-',
#  'upside',
#  '3/4',
#  '1100-samsung',
#  'that,',
#  'WELL',
#  '18',
#  'screen(real',
#  'BYE',
#  'replaced.',
#  'iPhone.',
#  '(0.9µm)',
#  'January',
#  'Headphones',
#  'parameter',
#  'hate',
#  '13999,',
#  'solid.',
#  'Like',
#  'videos',
#  'levels',
#  'category\n',
#  'distorted',
#  'Greater',
#  'products',
#  'notch',
#  'foolishly',
#  'solve',
#  'deta',
#  'continuously...Have',
#  'average',
#  'problem,during',
#  '10,',
#  'reviewing',
#  'VALUE',
#  'youngster',
#  'Gaming',
#  'now.Verdict:',
#  'between',
#  'all',
#  'niether',
#  '434.',
#  'refund',
#  'poor..',
#  'shockingly',
#  'respond',
#  'kind.',
#  'stylish',
#  'trend,',
#  'there.Cons:Selfie',
#  'earphone',
#  'buy.',
#  'pictures,',
#  'HDFC',
#  'pray',
#  'area,',
#  'C========================================Pro',
#  'uninstalled.\n',
#  'bhi',
#  'years,',
#  'stunning.MIUI',
#  'working4.Sound',
#  'hours.Cons:1.',
#  'Feb',
#  'spoke',
#  'light.4-',
#  "'stopped'.",
#  'sleek,',
#  '6-7k',
#  'Ear',
#  '13k..',
#  '(',
#  'mode.the',
#  'points,',
#  'feel.1',
#  'with.Notch',
#  'battery,',
#  'sale',
#  'points',
#  '75%.',
#  '(1st',
#  'competitors...',
#  'integrated',
#  'removable',
#  'u.*',
#  'slide',
#  'super',
#  '625Cheap',
#  'reach',
#  '"not',
#  'drop',
#  'include',
#  'side,',
#  'volte',
#  'Got',
#  'logo',
#  'loudspeaker',
#  'mercy',
#  '4k',
#  'BASIC',
#  'life',
#  'OneCheapCons',
#  '4go',
#  'icons,u',
#  'watching',
#  'that..',
#  'areas.red',
#  'storage.',
#  'round',
#  'switched',
#  'mode',
#  'amazing',
#  '10K',
#  'luck',
#  "offer..It's",
#  'description',
#  'voting',
#  '5.84"',
#  'Strongly',
#  'gio',
#  'worst',
#  'object/faces',
#  'PerformanceAs',
#  'OK',
#  'expecting',
#  'that.\n',
#  'GHz',
#  'rare',
#  '\nBattery:10/10',
#  'hotstar',
#  'aur',
#  'bastards',
#  'times,',
#  'Clean',
#  'Who',
#  'website,',
#  'bad.face',
#  'Heats',
#  'mobile.',
#  'been',
#  'Quite',
#  'returns',
#  'etc.).',
#  'end,',
#  'blurring',
#  'loading',
#  'lighting',
#  'continuous',
#  'role',
#  'Wifi',
#  'proves',
#  'focus',
#  'Mobile,',
#  'rocking..',
#  'usage',
#  'slightly',
#  'sensors2.',
#  'management:7/10I',
#  'seperate',
#  'world',
#  'thickness)',
#  'yet,',
#  '256GB',
#  "time.Can't",
#  '14k',
#  'Launcher',
#  'qualities',
#  'properly,',
#  'reception.',
#  'exceeded',
#  'mager',
#  'problem..if',
#  'resolve',
#  'nice\n',
#  'student.\n',
#  'verylittle',
#  'general',
#  'caused',
#  'viewing',
#  'spare.',
#  'you’re',
#  'time.Overall,',
#  '1',
#  'class.',
#  'budget',
#  'Lot',
#  'repair',
#  'tear',
#  'multitasking',
#  'supports',
#  'image',
#  "5'11)",
#  'funniest',
#  'considered',
#  '\nDnt',
#  'vibrant.',
#  'protective',
#  'review.\n',
#  'gud.',
#  'Sensors',
#  'processor),Dislikes:',
#  '&',
#  'hold',
#  "slotCon's",
#  'duplicate',
#  'larger',
#  'post',
#  'security.',
#  'mm',
#  '4000',
#  'life.',
#  'micro',
#  'Merely',
#  'capture.',
#  'confirmation',
#  'etc).',
#  'glass.',
#  'thn',
#  'To',
#  'photos....',
#  'model',
#  'tries.',
#  'ki',
#  'range;',
#  'octa-core',
#  'fast.',
#  'upgraded.LED',
#  'short.',
#  'update,',
#  'day.3.',
#  'experience',
#  'downgraded',
#  'limited,',
#  'delivery',
#  'hotter.....Hanging',
#  'inch.Pros',
#  'charging😙👎👎👎👎👎👎👎👎👎👎👎👎No',
#  'update.\n',
#  'Red',
#  'common',
#  'wide',
#  "ain't",
#  'transparent',
#  'sensors',
#  'buy',
#  'display2.',
#  'select',
#  'good-',
#  'us',
#  'India',
#  'convenient.',
#  'connectivity',
#  'Card',
#  'avoids',
#  'staff',
#  'completely.The',
#  'fact',
#  'Nd',
#  'pictures.AI',
#  'icici',
#  'sake',
#  '24',
#  'powered',
#  'ten',
#  'ppi',
#  'cable',
#  'Fast...*Conclusion*',
#  'rarely',
#  'CPU',
#  'Then,',
#  'exchange.....every',
#  'dislike',
#  'compromise',
#  'Xoami',
#  'pro,',
#  'almost',
#  'breaked',
#  'Dedicated',
#  'transferring',
#  'standard',
#  'gotten!',
#  'total',
#  'ram.',
#  'honest.',
#  'rest',
#  'Better',
#  '20th',
#  'Touch',
#  'downloaded',
#  'issue,',
#  '(cant',
#  'appeared',
#  'rate',
#  'puts',
#  'aswell',
#  'Nokia',
#  '9/10Front',
#  'NFCYou',
#  'cloud',
#  'aft',
#  'high',
#  'ugly,',
#  'Called',
#  'shitty',
#  'lost',
#  ':1.',
#  'somwtimes',
#  'Gyro',
#  '(which',
#  'Display2-',
#  'heart',
#  'Oct',
#  'unusable.3.',
#  'seller.',
#  'good.3.',
#  'features8)',
#  'Definitely',
#  '2015',
#  'wire',
#  '19:9',
#  '8k.\n',
#  '\nCamera',
#  'hone',
#  'ears.',
#  'fix',
#  'backThe',
#  'Gaming-',
#  'Monday',
#  'performance.\n',
#  'VARIENT',
#  'still...no',
#  'trouble',
#  'accepts',
#  'IM',
#  'notice',
#  'Secondary',
#  'How',
#  'worst.',
#  'over',
#  'generated.',
#  'help',
#  'service.best',
#  'conditions',
#  'models!\n',
#  'inproprtionate',
#  'light',
#  'like',
#  "camera.It's",
#  'priority',
#  'despite',
#  '20MP',
#  'blue',
#  'honestly',
#  'hd+.Its',
#  'person',
#  'again.',
#  'touchscreen',
#  'recieve',
#  'Scratchable',
#  '\nAnd',
#  'Micro-USB,',
#  'layer',
#  'talking',
#  'Average.',
#  'better-looking',
#  'grip',
#  'dilvery',
#  'flickeringCamera:',
#  'multitasked',
#  'tooAndroid',
#  'replacement.Today,',
#  'identical',
#  'phone...',
#  '10W',
#  'thanku',
#  'colour...Received',
#  'life,',
#  'center,then',
#  'work.One',
#  'One',
#  '18th',
#  '28th',
#  'size,',
#  'disappoint',
#  'clarity..Finger',
#  'great.\n',
#  'convenient',
#  'camera.the',
#  'wanted.',
#  'sure',
#  'handle',
#  'amazon',
#  'palms.',
#  'executives.\n',
#  'aspects',
#  'betterOverall',
#  '5MP',
#  'betterCamera:',
#  'FHD',
#  'fingerprint',
#  'quality__',
#  'reception4)',
#  'definition',
#  'winner',
#  'well',
#  'exchange',
#  'i',
#  'Redmi,',
#  'classCameraExcellent',
#  'left',
#  'update3.',
#  'cover',
#  'disappointed...\n',
#  'Somehow',
#  'pathetic.',
#  'Frony',
#  '4/5(disappointed',
#  'XIAOMI',
#  'point.',
#  'bank',
#  'LED.',
#  'horrible.',
#  'mistake',
#  '200',
#  'scrape',
#  '***',
#  'worked.',
#  'perfect',
#  'sellers',
#  'supported',
#  '(4G+3G),',
#  'fluid',
#  'underwhelming.2.',
#  'video,',
#  '100%And',
#  'deserve',
#  'screens)3.',
#  'Pro.They',
#  'HAND,',
#  'spends',
#  'suddenly',
#  '(thought',
#  'cam,',
#  'battery,design,build',
#  'forte',
#  'updates.\n',
#  'Pocket',
#  'membership.\n',
#  'charges',
#  'glass.2-',
#  'bad....',
#  'Data',
#  "here's",
#  'Presently',
#  'yet',
#  'Well',
#  'SIM+',
#  'installing',
#  'gaming.No',
#  'state.',
#  'disabled/uninstalled',
#  'MIUIPerformance*Snapdragon',
#  'performances',
#  'con',
#  'that',
#  'ONLY',
#  'Even',
#  'often.4.',
#  'battery.2.',
#  'six',
#  'frustrating.IDK',
#  'should',
#  'ordered',
#  'Pro.Conclusion:',
#  'phone..and',
#  'quiet',
#  'accepting',
#  'flopped',
#  'comments)Rear',
#  'update)ConsDisplay',
#  'Speaker',
#  'WhatsApp',
#  'flash',
#  'enough.',
#  'Kalkaji)\n',
#  'know,',
#  'qwality',
#  'Brightness',
#  'market',
#  'Loving',
#  'surprised',
#  'equipped',
#  'responsive',
#  'lover.',
#  'mega',
#  'focusing',
#  'freezing',
#  'fooling',
#  'pic/video,',
#  'phoneCamera',
#  'am',
#  '2hrs',
#  'Charge',
#  'something',
#  '1080p',
#  'issue.9.',
#  'developed',
#  'buying.For',
#  'activities',
#  'feature',
#  'rings',
#  'Moderate',
#  'iwas',
#  'operated',
#  'price(e.g',
#  'Jio',
#  'resale',
#  'Although',
#  'Charger-',
#  'time,',
#  "device.I'd",
#  'Redmii',
#  'heat',
#  ',BATTERY',
#  'drawer.BATTERY',
#  'thought.1.',
#  'discount.\n',
#  'interface.Phone',
#  'skin',
#  '11500',
#  'child,',
#  '636,',
#  'recall',
#  'K6',
#  'days.1)',
#  'ease',
#  'all.\n',
#  'avg.',
#  'that...',
#  'yearBut',
#  'retirement',
#  'retired',
#  'eye',
#  'consumes',
#  'slashed',
#  'wrong----thank',
#  'wonders...And',
#  'Back',
#  'idea...with',
#  '\nAwesome',
#  'Sometimes',
#  'flashing',
#  'having',
#  '10/10Sound',
#  'drawbacks,',
#  "It'll",
#  'IT',
#  'want',
#  'detailing',
#  'are,1.',
#  'lack',
#  'blank/black',
#  'durable',
#  '20,',
#  'Near',
#  'bit',
#  'instead',
#  'feeling..Superb',
#  'cleaning',
#  '32/64GB',
#  'fatser',
#  'Policy',
#  ',me',
#  'ONE',
#  'PDAF',
#  '(less',
#  'descent',
#  'priced',
#  'Mobile',
#  'time.3-',
#  '₹7200',
#  'purposes.',
#  'mixed',
#  'frame',
#  'similar',
#  'phones.',
#  '\nSuch',
#  'attracting',
#  'action',
#  'Varient',
#  'hesitation',
#  'Video',
#  'power',
#  '..i',
#  'arguably',
#  'Power',
#  'bug',
#  '19th',
#  '2.1',
#  'like,',
#  'wifi',
#  'processor6)',
#  'timr',
#  'usage.I',
#  'competitor',
#  'portraits',
#  'update..*Performance*',
#  '(5V',
#  '\nPros-',
#  '8.',
#  "isn't",
#  'part',
#  'review)CAMERA',
#  '1100',
#  'Model',
#  'thnks',
#  '(1.4µm),',
#  'stops',
#  'speaker.Battery-Godd',
#  'thing.All',
#  '\nWorst',
#  'coz',
#  '7,',
#  'use..',
#  'notifications',
#  'heater',
#  'works..',
#  '\nScreen-great',
#  'speaker)Things',
#  'choppy.',
#  'allow',
#  'there,',
#  "haven't",
#  'fast.I',
#  'enter',
#  'Lucky',
#  'invoice',
#  'loyal',
#  'outside..Light',
#  'sensor:-',
#  'white👎👎👎👎👎👎👎Viewing',
#  '\nHiI',
#  'stays',
#  'damn',
#  'picked',
#  'long',
#  'moneyIf',
#  'product.Thanks,',
#  'nice.-perfect',
#  'Also',
#  'weak',
#  'USA.',
#  'rude',
#  '626',
#  'STARS',
#  'functions.',
#  'VOLTE',
#  'cost).',
#  'hand*',
#  'functions',
#  'performance.',
#  'falls)Processor-9/10Extra',
#  'supplied',
#  'neither',
#  'exchange+',
#  'premium',
#  'isn’t',
#  'welcome',
#  '@xiaomi',
#  'shipped',
#  'budget.',
#  'festival.',
#  'phone;',
#  'bang',
#  "it's",
#  'break.\n',
#  'ok',
#  'Seamless',
#  'dicey',
#  "pro's",
#  '\nIt',
#  '13k,',
#  'junk',
#  '3s',
#  '\nits',
#  'extrmely',
#  'offers',
#  'Rear',
#  'openion',
#  '2018',
#  'it..Thats',
#  'features.but',
#  'potrait',
#  'proM1.with',
#  'it.\n',
#  'new',
#  'behavior',
#  'what',
#  'Management',
#  'smoothly',
#  'GB',
#  'mod',
#  'quick',
#  '6.3k,',
#  'seen',
#  'buyback',
#  'body',
#  'cameras,',
#  'hands,',
#  'Biggest',
#  'week',
#  'external',
#  'accidentally',
#  'adjustments.',
#  '.totally',
#  'continuously',
#  '3sTouch:',
#  'interphase',
#  'tray',
#  'worstFake',
#  'range,its',
#  'level',
#  'glitches',
#  'it.The',
#  'Cortex-A73',
#  '#miAnd',
#  'long!\n',
#  'also..dedicated',
#  'Loading',
#  'time(beauty',
#  'shock',
#  ',on',
#  'believe',
#  'processor.',
#  'soc',
#  '\nThings',
#  'standby...',
#  'harassment',
#  'T-Mobile',
#  'Samsung.-the',
#  'back..',
#  'ratio',
#  'except',
#  'create',
#  'kuch',
#  'gaming,',
#  'dim',
#  'noticing',
#  'sellI',
#  'mark',
#  'customers',
#  'were',
#  'finish',
#  'seemed',
#  'PUBG...but',
#  '\nThough',
#  'gaming.',
#  'How?',
#  'll',
#  'unread',
#  'disappointing,',
#  'specially',
#  '(probably',
#  'modified',
#  '(has',
#  'There',
#  'metal',
#  'Gmail.',
#  'with.Earlier',
#  ',Speaker',
#  'you......\n',
#  'sharing',
#  'great.Battery',
#  'kehena',
#  'Corning',
#  '\nWhy',
#  'there.',
#  'amazon,When',
#  'rom,magisk',
#  '3gb',
#  'more...Now',
#  'paper',
#  'condition',
#  'emergency.Tried',
#  'loudness',
#  'power.looks',
#  'moreover',
#  'read',
#  'fainted',
#  'notworking.I',
#  'setup.',
#  'among',
#  'protector',
#  'cm)*1080x2280',
#  '2000',
#  'Xiaomi...',
#  'would',
#  '\nCheap',
#  'Cared',
#  'WITHOUT',
#  'fortnite',
#  'problems',
#  'nags',
#  'device:',
#  '\nFellow',
#  'ask',
#  '5800.Super',
#  'man.5.',
#  'ok:Screen',
#  'problem/performance',
#  'it!\n',
#  'cameras.',
#  'deal!',
#  'bother',
#  '3.0',
#  'thd',
#  'frequent',
#  'lot',
#  'link,',
#  'worser',
#  'enjoyable',
#  'failed',
#  'excels',
#  'notch,it',
#  'snapping',
#  'might',
#  'tho',
#  'xhiomi',
#  'application',
#  'IncludedThe',
#  'decently',
#  '\nI',
#  'bug/use',
#  '\nHere’s',
#  'disappointed..',
#  'Asphalt',
#  'non-responsive',
#  'then',
#  '.if',
#  'glare',
#  'Fcucking',
#  'off',
#  'quality...\n',
#  'KING,this',
#  'Those',
#  'reme',
#  'fitted\n',
#  'ir',
#  'including',
#  'sneaked',
#  'diagnosed',
#  'configure.',
#  'handle.',
#  '4K',
#  'thinking',
#  'locking',
#  'normally',
#  'sometimes.',
#  'Yes',
#  '3.30PM',
#  'out',
#  'clicked.',
#  'schedules.',
#  'simple',
#  'refreshing',
#  'internet,',
#  'emergency',
#  ':-1)',
#  'twice',
#  'mod-',
#  'fell',
#  'accustomed',
#  'light.\n',
#  'abnoxiously',
#  'where.',
#  'launch.',
#  'final',
#  'MP)',
#  'an',
#  'rear,',
#  'Zenphone2',
#  'Xiaomi',
#  'searching',
#  '-*',
#  'worth.',
#  '\nDual',
#  'replacement.',
#  'effect',
#  'everI',
#  'minutes',
#  'phone.2.',
#  'prime,Redmi',
#  'handAudio',
#  'replacement.But',
#  'PLAY',
#  "I've",
#  'productSize:-',
#  'ticks',
#  'design,',
#  'jack.',
#  'point👎👎Charger',
#  'mention',
#  'ignorable.Still',
#  'clear,',
#  'toggle',
#  'cons:-1.',
#  'member',
#  'charging..*Camera*',
#  '\nAmazon',
#  'sounds',
#  'Black',
#  'ggod',
#  '.i',
#  '8.5/10.Performance:The',
#  'centre)',
#  'condition.8.',
#  'Tested',
#  'friendly,',
#  'choose',
#  'knew',
#  'better.Hardware',
#  'seperately.Have',
#  'means',
#  'performance-oriented',
#  'FITS',
#  'reachable,',
#  'VGA',
#  'better-',
#  'gold...camera',
#  'mAh.Camera-Quality',
#  'presence',
#  'tint',
#  'sim',
#  'HONEST',
#  'human',
#  'house',
#  'Awesome,',
#  '℅',
#  'decades',
#  'months.',
#  'product.this',
#  'Menu-Navigation',
#  'list.\n',
#  'anything',
#  'battery.-it',
#  'hi',
#  'unless',
#  'helps',
#  'food',
#  'behalf',
#  "b'coz",
#  'much.Sound-You',
#  'into',
#  'expectations.',
#  'fit',
#  'absolute',
#  'Ads',
#  'Instead',
#  'detailed',
#  'Hybrid',
#  'results',
#  'revamping.',
#  'disabling',
#  'recording',
#  'waste',
#  'fake',
#  'Aluminum',
#  'tour',
#  'uwing',
#  'Bad',
#  'is:',
#  '..(if',
#  'own',
#  'efficiently..',
#  'seem',
#  ...]
